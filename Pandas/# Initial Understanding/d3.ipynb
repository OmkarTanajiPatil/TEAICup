# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


import warnings
warnings.filterwarnings('ignore')

# %%
import os

# %%
dirs = os.listdir()
dirs
# Out:
# ['5DayCamera.ipynb',
#  '5DayCameraMetadata.ipynb',
#  'insights.txt',
#  'main.ipynb',
#  'metadata_l2.ipynb',
#  'newCombinedDatasets',
#  'OCA-5_days_sample data',
#  'OCA-5_days_sample data.zip',
#  'Sample_camera_data_10000.csv']

# %%
data = os.listdir("OCA-5_days_sample data")
data
# Out:
# ['5days_Metadata_L1.csv',
#  '5days_of_camera_data.csv',
#  'description.md',
#  'Metadata_L2.csv']

# %%
metaData = pd.read_csv("./OCA-5_days_sample data/Metadata_L2.csv", sep=";", encoding='latin1')
metaData
# Out:
#       qcpc_event_id qcpc_event_machine_id  \
# 0       27601227596                 S-276
# 1       27601226196                 S-276
# 2       26803927805                 S-268
# 3       26903485075                 S-269
# 4       22600234145                 S-226
# ...             ...                   ...
# 9910    27601228404                 S-276
# 9911    26803918960                 S-268
# 9912    26903485594                 S-269
# 9913    27601228836                 S-276
# 9914    27601226323                 S-276
#
#       qcpc_event_machine_status_active_code qcpc_event_create_timestamp  \
# 0                                       200         2025-12-08 23:33:41
# 1                                       200         2025-12-05 11:30:08
# 2                                     30000         2025-12-06 10:33:21
# 3                                     30000         2025-12-08 21:48:34
# 4                                       200         2025-12-08 07:13:26
# ...

# %%
sample = metaData.sample()

# %%
print(metaData.iloc[-1, :].qcpc_event_error_text)
# Out:
#  I-Kasten hinten: Cur= 1.888 LTL= 1.780 UTL= 1.880

# %%
actualMetaData = metaData[metaData["qcpc_event_machine_status_active_code"] == 200]
actualMetaData
# Out:
#       qcpc_event_id qcpc_event_machine_id  \
# 0       27601227596                 S-276
# 1       27601226196                 S-276
# 4       22600234145                 S-226
# 5       26903483904                 S-269
# 6       27601228449                 S-276
# ...             ...                   ...
# 9909    22300227531                 S-223
# 9910    27601228404                 S-276
# 9912    26903485594                 S-269
# 9913    27601228836                 S-276
# 9914    27601226323                 S-276
#
#       qcpc_event_machine_status_active_code qcpc_event_create_timestamp  \
# 0                                       200         2025-12-08 23:33:41
# 1                                       200         2025-12-05 11:30:08
# 4                                       200         2025-12-08 07:13:26
# 5                                       200         2025-12-05 07:52:59
# 6                                       200         2025-12-09 05:12:42
# ...

# %%
actualMetaData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7102 entries, 0 to 9914
# Data columns (total 8 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   qcpc_event_id                          7102 non-null   int64
#  1   qcpc_event_machine_id                  7102 non-null   object
#  2   qcpc_event_machine_status_active_code  7102 non-null   int64
#  3   qcpc_event_create_timestamp            7102 non-null   object
#  4   qcpc_event_machine_module_description  7102 non-null   object
#  5   qcpc_event_part_number                 7102 non-null   object
#  6   qcpc_event_error_text                  7102 non-null   object
#  7   qcpc_event_machine_stop_code           7102 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 499.4+ KB

# %%
actualMetaData.nunique()
# Out:
# qcpc_event_id                            7102
# qcpc_event_machine_id                       6
# qcpc_event_machine_status_active_code       1
# qcpc_event_create_timestamp              4614
# qcpc_event_machine_module_description       2
# qcpc_event_part_number                      6
# qcpc_event_error_text                    1734
# qcpc_event_machine_stop_code                2
# dtype: int64

# %%
for i in actualMetaData.columns:
    if len(i.split("_")) >= 2:
        newName = "_".join(i.split("_")[2:])
        actualMetaData  = actualMetaData.rename(columns={i: newName})

# %%
actualMetaData
# Out:
#                id machine_id  machine_status_active_code     create_timestamp  \
# 0     27601227596      S-276                         200  2025-12-08 23:33:41
# 1     27601226196      S-276                         200  2025-12-05 11:30:08
# 4     22600234145      S-226                         200  2025-12-08 07:13:26
# 5     26903483904      S-269                         200  2025-12-05 07:52:59
# 6     27601228449      S-276                         200  2025-12-09 05:12:42
# ...           ...        ...                         ...                  ...
# 9909  22300227531      S-223                         200  2025-12-09 09:56:49
# 9910  27601228404      S-276                         200  2025-12-09 04:49:32
# 9912  26903485594      S-269                         200  2025-12-09 13:37:47
# 9913  27601228836      S-276                         200  2025-12-09 18:37:08
# 9914  27601226323      S-276                         200  2025-12-05 11:51:55
#
# ...

# %%
actualMetaData[actualMetaData.machine_stop_code == 1]
# Out:
#                id machine_id  machine_status_active_code     create_timestamp  \
# 61    22300227210      S-223                         200  2025-12-07 11:02:14
# 100   22300227097      S-223                         200  2025-12-07 00:40:51
# 139   22300226720      S-223                         200  2025-12-05 07:56:31
# 163   22300227440      S-223                         200  2025-12-08 18:03:15
# 434   22300227446      S-223                         200  2025-12-08 19:07:40
# ...           ...        ...                         ...                  ...
# 8976  22300226909      S-223                         200  2025-12-05 20:23:03
# 9103  22300227389      S-223                         200  2025-12-08 13:27:40
# 9235  22300227215      S-223                         200  2025-12-07 12:18:05
# 9275  22300226775      S-223                         200  2025-12-05 15:54:04
# 9420  22300227255      S-223                         200  2025-12-07 22:13:03
#
# ...

# %%
metaDataCamera = metaData[metaData.qcpc_event_machine_status_active_code == 200]

# %%
metaDataCamera
# Out:
#       qcpc_event_id qcpc_event_machine_id  \
# 0       27601227596                 S-276
# 1       27601226196                 S-276
# 4       22600234145                 S-226
# 5       26903483904                 S-269
# 6       27601228449                 S-276
# ...             ...                   ...
# 9909    22300227531                 S-223
# 9910    27601228404                 S-276
# 9912    26903485594                 S-269
# 9913    27601228836                 S-276
# 9914    27601226323                 S-276
#
#       qcpc_event_machine_status_active_code qcpc_event_create_timestamp  \
# 0                                       200         2025-12-08 23:33:41
# 1                                       200         2025-12-05 11:30:08
# 4                                       200         2025-12-08 07:13:26
# 5                                       200         2025-12-05 07:52:59
# 6                                       200         2025-12-09 05:12:42
# ...

# %%
metaDataCamera.qcpc_event_machine_id.unique()
# Out:
# array(['S-276', 'S-226', 'S-269', 'S-268', 'S-223', 'S-278'], dtype=object)

# %%
metaDataCamera.dtypes
# Out:
# qcpc_event_id                             int64
# qcpc_event_machine_id                    object
# qcpc_event_machine_status_active_code     int64
# qcpc_event_create_timestamp              object
# qcpc_event_machine_module_description    object
# qcpc_event_part_number                   object
# qcpc_event_error_text                    object
# qcpc_event_machine_stop_code              int64
# dtype: object

# %%
s = metaDataCamera.sample()
s
print(s.qcpc_event_error_text.values)
# Out:
# [' Teil 2 Federlötstelle: Cur= 0.000 LTL= 0.900 UTL= 2.000']

# %%
s.qcpc_event_error_text.dtype
# Out:
# dtype('O')
