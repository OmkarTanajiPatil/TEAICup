# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
md = pd.read_csv("./OCA-5_days_sample data/5days_Metadata_L1.csv", sep=";", encoding="latin1")
md
# Out:
#      hydra_plant_instance_name machine_id machine_event_start_timestamp  \
# 0                        WOERT      S-223           2025-12-05 06:00:00
# 1                        WOERT      S-223           2025-12-05 06:01:58
# 2                        WOERT      S-223           2025-12-05 06:40:59
# 3                        WOERT      S-223           2025-12-05 06:43:08
# 4                        WOERT      S-223           2025-12-05 06:56:26
# ...                        ...        ...                           ...
# 3176                     WOERT      S-278           2025-12-09 20:37:52
# 3177                     WOERT      S-278           2025-12-09 20:38:37
# 3178                     WOERT      S-278           2025-12-09 20:54:44
# 3179                     WOERT      S-278           2025-12-09 21:38:55
# 3180                     WOERT      S-278           2025-12-09 22:00:00
#
#      machine_event_start_end_timestamp  machine_status_code  \
# ...

# %%
md[
    (md.machine_status_code == 200)
    # & (md.machine_status_name != "Produktion")
    # & (md.part_number == "5-963715-1")
]
# Out:
#      hydra_plant_instance_name machine_id machine_event_start_timestamp  \
# 2                        WOERT      S-223           2025-12-05 06:40:59
# 4                        WOERT      S-223           2025-12-05 06:56:26
# 6                        WOERT      S-223           2025-12-05 07:07:36
# 8                        WOERT      S-223           2025-12-05 07:09:33
# 10                       WOERT      S-223           2025-12-05 07:11:18
# ...                        ...        ...                           ...
# 3168                     WOERT      S-278           2025-12-09 20:23:54
# 3170                     WOERT      S-278           2025-12-09 20:25:09
# 3172                     WOERT      S-278           2025-12-09 20:31:13
# 3174                     WOERT      S-278           2025-12-09 20:31:52
# 3176                     WOERT      S-278           2025-12-09 20:37:52
#
#      machine_event_start_end_timestamp  machine_status_code  \
# ...

# %%
md1 = md[md.machine_status_code == 200]
md1
# Out:
#      hydra_plant_instance_name machine_id machine_event_start_timestamp  \
# 2                        WOERT      S-223           2025-12-05 06:40:59
# 4                        WOERT      S-223           2025-12-05 06:56:26
# 6                        WOERT      S-223           2025-12-05 07:07:36
# 8                        WOERT      S-223           2025-12-05 07:09:33
# 10                       WOERT      S-223           2025-12-05 07:11:18
# ...                        ...        ...                           ...
# 3168                     WOERT      S-278           2025-12-09 20:23:54
# 3170                     WOERT      S-278           2025-12-09 20:25:09
# 3172                     WOERT      S-278           2025-12-09 20:31:13
# 3174                     WOERT      S-278           2025-12-09 20:31:52
# 3176                     WOERT      S-278           2025-12-09 20:37:52
#
#      machine_event_start_end_timestamp  machine_status_code  \
# ...

# %%
md1.machine_event_start_timestamp.min()
# Out:
# '2025-12-05 06:00:00'

# %%
md.machine_event_start_timestamp = pd.to_datetime(md.machine_event_start_timestamp)
md.machine_event_start_end_timestamp = pd.to_datetime(
    md.machine_event_start_end_timestamp
)
