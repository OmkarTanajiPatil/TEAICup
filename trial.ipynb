# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


import warnings
warnings.filterwarnings('ignore')

# %%
# List of random numbers bn 1 to 2.2
lt = np.array(np.random.uniform(1, 2.2, 1000))

# %%
np.sum((lt < 1.25) | (lt > 2))
# Out:
# np.int64(377)
