# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import polars as pl

import warnings
warnings.filterwarnings('ignore')

# %%
df = pl.read_csv(
    r"M:\TEAICup Data\60days_Metadata_L1.csv", separator=";", encoding="latin1"
)

# %%
df
# Out:
# shape: (40_736, 8)
# ┌────────────┬────────────┬────────────┬───────────┬───────────┬───────────┬───────────┬───────────┐
# │ hydra_plan ┆ machine_id ┆ machine_ev ┆ machine_e ┆ machine_s ┆ machine_s ┆ part_numb ┆ tool_numb │
# │ t_instance ┆ ---        ┆ ent_start_ ┆ vent_star ┆ tatus_cod ┆ tatus_nam ┆ er        ┆ er        │
# │ _name      ┆ str        ┆ timestamp  ┆ t_end_tim ┆ e         ┆ e         ┆ ---       ┆ ---       │
# │ ---        ┆            ┆ ---        ┆ est…      ┆ ---       ┆ ---       ┆ str       ┆ str       │
# │ str        ┆            ┆ str        ┆ ---       ┆ i64       ┆ str       ┆           ┆           │
# │            ┆            ┆            ┆ str       ┆           ┆           ┆           ┆           │
# ╞════════════╪════════════╪════════════╪═══════════╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ WOERT      ┆ S-223      ┆ 2025-09-30 ┆ 2025-09-3 ┆ 200       ┆ Produktio ┆ 5-963715- ┆ S0275910  │
# │            ┆            ┆ 06:00:00   ┆ 0         ┆           ┆ n         ┆ 1         ┆           │
# │            ┆            ┆            ┆ 06:02:57  ┆           ┆           ┆           ┆           │
# │ WOERT      ┆ S-223      ┆ 2025-09-30 ┆ 2025-09-3 ┆ 219       ┆ Kurzzeits ┆ 5-963715- ┆ S0275910  │
# │            ┆            ┆ 06:02:57   ┆ 0         ┆           ┆ toerung   ┆ 1         ┆           │
# │            ┆            ┆            ┆ 06:02:57  ┆           ┆           ┆           ┆           │
# │ WOERT      ┆ S-223      ┆ 2025-09-30 ┆ 2025-09-3 ┆ 200       ┆ Produktio ┆ 5-963715- ┆ S0275910  │
# │            ┆            ┆ 06:02:57   ┆ 0         ┆           ┆ n         ┆ 1         ┆           │
# │            ┆            ┆            ┆ 06:28:21  ┆           ┆           ┆           ┆           │
# │ WOERT      ┆ S-223      ┆ 2025-09-30 ┆ 2025-09-3 ┆ 219       ┆ Kurzzeits ┆ 5-963715- ┆ S0275910  │
# │            ┆            ┆ 06:28:21   ┆ 0         ┆           ┆ toerung   ┆ 1         ┆           │
# │            ┆            ┆            ┆ 06:29:29  ┆           ┆           ┆           ┆           │
# │ WOERT      ┆ S-223      ┆ 2025-09-30 ┆ 2025-09-3 ┆ 200       ┆ Produktio ┆ 5-963715- ┆ S0275910  │
# │            ┆            ┆ 06:29:29   ┆ 0         ┆           ┆ n         ┆ 1         ┆           │
# │            ┆            ┆            ┆ 06:54:52  ┆           ┆           ┆           ┆           │
# │ …          ┆ …          ┆ …          ┆ …         ┆ …         ┆ …         ┆ …         ┆ …         │
# │ WOERT      ┆ S-278      ┆ 2025-12-01 ┆ 2025-12-0 ┆ 999       ┆ Schichtpa ┆ 5-2208763 ┆ S1829103  │
# │            ┆            ┆ 06:00:00   ┆ 1         ┆           ┆ use       ┆ -3        ┆           │
# │            ┆            ┆            ┆ 06:22:28  ┆           ┆           ┆           ┆           │
# │ WOERT      ┆ S-278      ┆ 2025-12-01 ┆ 2025-12-0 ┆ 115       ┆ Einstelle ┆ 5-2208763 ┆ S1829103  │
# │            ┆            ┆ 06:22:28   ┆ 1         ┆           ┆ n WKZ     ┆ -3        ┆           │
# │            ┆            ┆            ┆ 13:36:58  ┆           ┆ Umb.      ┆           ┆           │
# │ WOERT      ┆ S-278      ┆ 2025-12-01 ┆ 2025-12-0 ┆ 999       ┆ Schichtpa ┆ 5-2208763 ┆ S1829103  │
# │            ┆            ┆ 13:36:58   ┆ 1         ┆           ┆ use       ┆ -3        ┆           │
# │            ┆            ┆            ┆ 13:59:59  ┆           ┆           ┆           ┆           │
# │ WOERT      ┆ S-278      ┆ 2025-12-01 ┆ 2025-12-0 ┆ 999       ┆ Schichtpa ┆ 5-2208763 ┆ S1829103  │
# │            ┆            ┆ 13:59:59   ┆ 1         ┆           ┆ use       ┆ -3        ┆           │
# │            ┆            ┆            ┆ 22:00:00  ┆           ┆           ┆           ┆           │
# │ WOERT      ┆ S-278      ┆ 2025-12-01 ┆ 2025-12-0 ┆ 999       ┆ Schichtpa ┆ 5-2208763 ┆ S1829103  │
# │            ┆            ┆ 22:00:00   ┆ 2         ┆           ┆ use       ┆ -3        ┆           │
# │            ┆            ┆            ┆ 06:00:00  ┆           ┆           ┆           ┆           │
# └────────────┴────────────┴────────────┴───────────┴───────────┴───────────┴───────────┴───────────┘

# %% [markdown]
# ## Some Basic Filters
# + Removing Single valued attribute
# + Machine code 200

# %%
single_valued_columns = ["hydra_plant_instance_name"]

for col in single_valued_columns:
    if col in df.columns:
        df = df.drop(col)
df
# Out:
# shape: (40_736, 7)
# ┌────────────┬──────────────┬──────────────┬─────────────┬─────────────┬─────────────┬─────────────┐
# │ machine_id ┆ machine_even ┆ machine_even ┆ machine_sta ┆ machine_sta ┆ part_number ┆ tool_number │
# │ ---        ┆ t_start_time ┆ t_start_end_ ┆ tus_code    ┆ tus_name    ┆ ---         ┆ ---         │
# │ str        ┆ stamp        ┆ timest…      ┆ ---         ┆ ---         ┆ str         ┆ str         │
# │            ┆ ---          ┆ ---          ┆ i64         ┆ str         ┆             ┆             │
# │            ┆ str          ┆ str          ┆             ┆             ┆             ┆             │
# ╞════════════╪══════════════╪══════════════╪═════════════╪═════════════╪═════════════╪═════════════╡
# │ S-223      ┆ 2025-09-30   ┆ 2025-09-30   ┆ 200         ┆ Produktion  ┆ 5-963715-1  ┆ S0275910    │
# │            ┆ 06:00:00     ┆ 06:02:57     ┆             ┆             ┆             ┆             │
# │ S-223      ┆ 2025-09-30   ┆ 2025-09-30   ┆ 219         ┆ Kurzzeitsto ┆ 5-963715-1  ┆ S0275910    │
# │            ┆ 06:02:57     ┆ 06:02:57     ┆             ┆ erung       ┆             ┆             │
# │ S-223      ┆ 2025-09-30   ┆ 2025-09-30   ┆ 200         ┆ Produktion  ┆ 5-963715-1  ┆ S0275910    │
# │            ┆ 06:02:57     ┆ 06:28:21     ┆             ┆             ┆             ┆             │
# │ S-223      ┆ 2025-09-30   ┆ 2025-09-30   ┆ 219         ┆ Kurzzeitsto ┆ 5-963715-1  ┆ S0275910    │
# │            ┆ 06:28:21     ┆ 06:29:29     ┆             ┆ erung       ┆             ┆             │
# │ S-223      ┆ 2025-09-30   ┆ 2025-09-30   ┆ 200         ┆ Produktion  ┆ 5-963715-1  ┆ S0275910    │
# │            ┆ 06:29:29     ┆ 06:54:52     ┆             ┆             ┆             ┆             │
# │ …          ┆ …            ┆ …            ┆ …           ┆ …           ┆ …           ┆ …           │
# │ S-278      ┆ 2025-12-01   ┆ 2025-12-01   ┆ 999         ┆ Schichtpaus ┆ 5-2208763-3 ┆ S1829103    │
# │            ┆ 06:00:00     ┆ 06:22:28     ┆             ┆ e           ┆             ┆             │
# │ S-278      ┆ 2025-12-01   ┆ 2025-12-01   ┆ 115         ┆ Einstellen  ┆ 5-2208763-3 ┆ S1829103    │
# │            ┆ 06:22:28     ┆ 13:36:58     ┆             ┆ WKZ Umb.    ┆             ┆             │
# │ S-278      ┆ 2025-12-01   ┆ 2025-12-01   ┆ 999         ┆ Schichtpaus ┆ 5-2208763-3 ┆ S1829103    │
# │            ┆ 13:36:58     ┆ 13:59:59     ┆             ┆ e           ┆             ┆             │
# │ S-278      ┆ 2025-12-01   ┆ 2025-12-01   ┆ 999         ┆ Schichtpaus ┆ 5-2208763-3 ┆ S1829103    │
# │            ┆ 13:59:59     ┆ 22:00:00     ┆             ┆ e           ┆             ┆             │
# │ S-278      ┆ 2025-12-01   ┆ 2025-12-02   ┆ 999         ┆ Schichtpaus ┆ 5-2208763-3 ┆ S1829103    │
# │            ┆ 22:00:00     ┆ 06:00:00     ┆             ┆ e           ┆             ┆             │
# └────────────┴──────────────┴──────────────┴─────────────┴─────────────┴─────────────┴─────────────┘

# %%
df = df.filter(pl.col("machine_status_code") == 200)
df
# Out:
# shape: (19_881, 7)
# ┌────────────┬──────────────┬──────────────┬─────────────┬─────────────┬─────────────┬─────────────┐
# │ machine_id ┆ machine_even ┆ machine_even ┆ machine_sta ┆ machine_sta ┆ part_number ┆ tool_number │
# │ ---        ┆ t_start_time ┆ t_start_end_ ┆ tus_code    ┆ tus_name    ┆ ---         ┆ ---         │
# │ str        ┆ stamp        ┆ timest…      ┆ ---         ┆ ---         ┆ str         ┆ str         │
# │            ┆ ---          ┆ ---          ┆ i64         ┆ str         ┆             ┆             │
# │            ┆ str          ┆ str          ┆             ┆             ┆             ┆             │
# ╞════════════╪══════════════╪══════════════╪═════════════╪═════════════╪═════════════╪═════════════╡
# │ S-223      ┆ 2025-09-30   ┆ 2025-09-30   ┆ 200         ┆ Produktion  ┆ 5-963715-1  ┆ S0275910    │
# │            ┆ 06:00:00     ┆ 06:02:57     ┆             ┆             ┆             ┆             │
# │ S-223      ┆ 2025-09-30   ┆ 2025-09-30   ┆ 200         ┆ Produktion  ┆ 5-963715-1  ┆ S0275910    │
# │            ┆ 06:02:57     ┆ 06:28:21     ┆             ┆             ┆             ┆             │
# │ S-223      ┆ 2025-09-30   ┆ 2025-09-30   ┆ 200         ┆ Produktion  ┆ 5-963715-1  ┆ S0275910    │
# │            ┆ 06:29:29     ┆ 06:54:52     ┆             ┆             ┆             ┆             │
# │ S-223      ┆ 2025-09-30   ┆ 2025-09-30   ┆ 200         ┆ Produktion  ┆ 5-963715-1  ┆ S0275910    │
# │            ┆ 06:59:18     ┆ 06:59:27     ┆             ┆             ┆             ┆             │
# │ S-223      ┆ 2025-09-30   ┆ 2025-09-30   ┆ 200         ┆ Produktion  ┆ 5-963715-1  ┆ S0275910    │
# │            ┆ 07:00:14     ┆ 07:00:28     ┆             ┆             ┆             ┆             │
# │ …          ┆ …            ┆ …            ┆ …           ┆ …           ┆ …           ┆ …           │
# │ S-278      ┆ 2025-11-21   ┆ 2025-11-21   ┆ 200         ┆ Produktion  ┆ 1-2208762-3 ┆ S1829103    │
# │            ┆ 13:02:30     ┆ 13:04:00     ┆             ┆             ┆             ┆             │
# │ S-278      ┆ 2025-11-21   ┆ 2025-11-21   ┆ 200         ┆ Produktion  ┆ 1-2208762-3 ┆ S1829103    │
# │            ┆ 13:04:14     ┆ 13:05:24     ┆             ┆             ┆             ┆             │
# │ S-278      ┆ 2025-11-21   ┆ 2025-11-21   ┆ 200         ┆ Produktion  ┆ 1-2208762-3 ┆ S1829103    │
# │            ┆ 13:07:10     ┆ 13:08:34     ┆             ┆             ┆             ┆             │
# │ S-278      ┆ 2025-11-21   ┆ 2025-11-21   ┆ 200         ┆ Produktion  ┆ 1-2208762-3 ┆ S1829103    │
# │            ┆ 13:08:41     ┆ 13:08:58     ┆             ┆             ┆             ┆             │
# │ S-278      ┆ 2025-11-21   ┆ 2025-11-21   ┆ 200         ┆ Produktion  ┆ 1-2208762-3 ┆ S1829103    │
# │            ┆ 13:09:02     ┆ 13:09:21     ┆             ┆             ┆             ┆             │
# └────────────┴──────────────┴──────────────┴─────────────┴─────────────┴─────────────┴─────────────┘

# %%
single_valued_columns = ["machine_status_name", "machine_status_code"]

for col in single_valued_columns:
    if col in df.columns:
        df = df.drop(col)
df
# Out:
# shape: (19_881, 5)
# ┌────────────┬────────────────────────────┬────────────────────────────┬─────────────┬─────────────┐
# │ machine_id ┆ machine_event_start_timest ┆ machine_event_start_end_ti ┆ part_number ┆ tool_number │
# │ ---        ┆ amp                        ┆ mest…                      ┆ ---         ┆ ---         │
# │ str        ┆ ---                        ┆ ---                        ┆ str         ┆ str         │
# │            ┆ str                        ┆ str                        ┆             ┆             │
# ╞════════════╪════════════════════════════╪════════════════════════════╪═════════════╪═════════════╡
# │ S-223      ┆ 2025-09-30 06:00:00        ┆ 2025-09-30 06:02:57        ┆ 5-963715-1  ┆ S0275910    │
# │ S-223      ┆ 2025-09-30 06:02:57        ┆ 2025-09-30 06:28:21        ┆ 5-963715-1  ┆ S0275910    │
# │ S-223      ┆ 2025-09-30 06:29:29        ┆ 2025-09-30 06:54:52        ┆ 5-963715-1  ┆ S0275910    │
# │ S-223      ┆ 2025-09-30 06:59:18        ┆ 2025-09-30 06:59:27        ┆ 5-963715-1  ┆ S0275910    │
# │ S-223      ┆ 2025-09-30 07:00:14        ┆ 2025-09-30 07:00:28        ┆ 5-963715-1  ┆ S0275910    │
# │ …          ┆ …                          ┆ …                          ┆ …           ┆ …           │
# │ S-278      ┆ 2025-11-21 13:02:30        ┆ 2025-11-21 13:04:00        ┆ 1-2208762-3 ┆ S1829103    │
# │ S-278      ┆ 2025-11-21 13:04:14        ┆ 2025-11-21 13:05:24        ┆ 1-2208762-3 ┆ S1829103    │
# │ S-278      ┆ 2025-11-21 13:07:10        ┆ 2025-11-21 13:08:34        ┆ 1-2208762-3 ┆ S1829103    │
# │ S-278      ┆ 2025-11-21 13:08:41        ┆ 2025-11-21 13:08:58        ┆ 1-2208762-3 ┆ S1829103    │
# │ S-278      ┆ 2025-11-21 13:09:02        ┆ 2025-11-21 13:09:21        ┆ 1-2208762-3 ┆ S1829103    │
# └────────────┴────────────────────────────┴────────────────────────────┴─────────────┴─────────────┘

# %% [markdown]
# ### Converting times into timestamp

# %%
cols_to_timestamp = [
    "machine_event_start_timestamp",
    "machine_event_start_end_timestamp",
]
df = df.with_columns(
    pl.col(cols_to_timestamp).str.to_datetime()
)
df
# Out:
# shape: (19_881, 5)
# ┌────────────┬────────────────────────────┬────────────────────────────┬─────────────┬─────────────┐
# │ machine_id ┆ machine_event_start_timest ┆ machine_event_start_end_ti ┆ part_number ┆ tool_number │
# │ ---        ┆ amp                        ┆ mest…                      ┆ ---         ┆ ---         │
# │ str        ┆ ---                        ┆ ---                        ┆ str         ┆ str         │
# │            ┆ datetime[μs]               ┆ datetime[μs]               ┆             ┆             │
# ╞════════════╪════════════════════════════╪════════════════════════════╪═════════════╪═════════════╡
# │ S-223      ┆ 2025-09-30 06:00:00        ┆ 2025-09-30 06:02:57        ┆ 5-963715-1  ┆ S0275910    │
# │ S-223      ┆ 2025-09-30 06:02:57        ┆ 2025-09-30 06:28:21        ┆ 5-963715-1  ┆ S0275910    │
# │ S-223      ┆ 2025-09-30 06:29:29        ┆ 2025-09-30 06:54:52        ┆ 5-963715-1  ┆ S0275910    │
# │ S-223      ┆ 2025-09-30 06:59:18        ┆ 2025-09-30 06:59:27        ┆ 5-963715-1  ┆ S0275910    │
# │ S-223      ┆ 2025-09-30 07:00:14        ┆ 2025-09-30 07:00:28        ┆ 5-963715-1  ┆ S0275910    │
# │ …          ┆ …                          ┆ …                          ┆ …           ┆ …           │
# │ S-278      ┆ 2025-11-21 13:02:30        ┆ 2025-11-21 13:04:00        ┆ 1-2208762-3 ┆ S1829103    │
# │ S-278      ┆ 2025-11-21 13:04:14        ┆ 2025-11-21 13:05:24        ┆ 1-2208762-3 ┆ S1829103    │
# │ S-278      ┆ 2025-11-21 13:07:10        ┆ 2025-11-21 13:08:34        ┆ 1-2208762-3 ┆ S1829103    │
# │ S-278      ┆ 2025-11-21 13:08:41        ┆ 2025-11-21 13:08:58        ┆ 1-2208762-3 ┆ S1829103    │
# │ S-278      ┆ 2025-11-21 13:09:02        ┆ 2025-11-21 13:09:21        ┆ 1-2208762-3 ┆ S1829103    │
# └────────────┴────────────────────────────┴────────────────────────────┴─────────────┴─────────────┘

# %% [markdown]
# ### Sorting based on start time

# %%
df = df.sort("machine_event_start_timestamp")
df
# Out:
# shape: (19_881, 5)
# ┌────────────┬────────────────────────────┬────────────────────────────┬─────────────┬─────────────┐
# │ machine_id ┆ machine_event_start_timest ┆ machine_event_start_end_ti ┆ part_number ┆ tool_number │
# │ ---        ┆ amp                        ┆ mest…                      ┆ ---         ┆ ---         │
# │ str        ┆ ---                        ┆ ---                        ┆ str         ┆ str         │
# │            ┆ datetime[μs]               ┆ datetime[μs]               ┆             ┆             │
# ╞════════════╪════════════════════════════╪════════════════════════════╪═════════════╪═════════════╡
# │ S-223      ┆ 2025-09-30 06:00:00        ┆ 2025-09-30 06:02:57        ┆ 5-963715-1  ┆ S0275910    │
# │ S-226      ┆ 2025-09-30 06:00:00        ┆ 2025-09-30 06:02:14        ┆ 5-965906-1  ┆ S0025195    │
# │ S-268      ┆ 2025-09-30 06:00:00        ┆ 2025-09-30 06:05:24        ┆ 2-1703930-2 ┆ S1829661    │
# │ S-269      ┆ 2025-09-30 06:00:00        ┆ 2025-09-30 06:13:26        ┆ 2-1703930-1 ┆ S1956413    │
# │ S-223      ┆ 2025-09-30 06:02:57        ┆ 2025-09-30 06:28:21        ┆ 5-963715-1  ┆ S0275910    │
# │ …          ┆ …                          ┆ …                          ┆ …           ┆ …           │
# │ S-276      ┆ 2025-12-02 05:41:14        ┆ 2025-12-02 06:00:00        ┆ 7-1452668-3 ┆ S1829585    │
# │ S-269      ┆ 2025-12-02 05:41:30        ┆ 2025-12-02 05:44:57        ┆ 2-1703930-1 ┆ S1956413    │
# │ S-226      ┆ 2025-12-02 05:42:33        ┆ 2025-12-02 05:44:47        ┆ 5-965906-1  ┆ S0025195    │
# │ S-226      ┆ 2025-12-02 05:47:06        ┆ 2025-12-02 05:49:55        ┆ 5-965906-1  ┆ S0025195    │
# │ S-269      ┆ 2025-12-02 05:49:46        ┆ 2025-12-02 05:52:37        ┆ 2-1703930-1 ┆ S1956413    │
# └────────────┴────────────────────────────┴────────────────────────────┴─────────────┴─────────────┘

# %% [markdown]
# ## Saving the data to parquet

# %%
df.write_parquet(r"E:\Learning\TEAI Cup\Polars\# Parquets\d1_60_1.parquet")
