# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import polars as pl

import warnings
warnings.filterwarnings('ignore')

# %%
df = pl.read_parquet(
    r"E:\Learning\TEAI Cup\Data\Parquet Data\original_parquets\5days_of_camera_data.parquet"
)

# %%
df
# Out:
# shape: (2_408_396, 6)
# ┌──────────────┬─────────────────┬─────────────────┬─────────────────┬────────────┬────────────────┐
# │ device_name  ┆ machine_definit ┆ variable_name   ┆ value           ┆ timestamp  ┆ variable_attri │
# │ ---          ┆ ion             ┆ ---             ┆ ---             ┆ ---        ┆ bute           │
# │ str          ┆ ---             ┆ str             ┆ str             ┆ str        ┆ ---            │
# │              ┆ str             ┆                 ┆                 ┆            ┆ str            │
# ╞══════════════╪═════════════════╪═════════════════╪═════════════════╪════════════╪════════════════╡
# │ de512stmp223 ┆ spark-machine-o ┆ teil1GapX       ┆ 0.498,0.496,0.4 ┆ 2025-12-10 ┆ lowerLimit:    │
# │              ┆ tto-vision-dyna ┆                 ┆ 96,0.498,0.496, ┆ 04:16:46   ┆ -0.06499,      │
# │              ┆ …               ┆                 ┆ …               ┆            ┆ upperLim…      │
# ...

# %%
df.shape
# Out:
# (2408396, 6)

# %%
df.dtypes
# Out:
# [String, String, String, String, String, String]

# %% [markdown]
# # Selecting and Filtering

# %% [markdown]
# ## 1 indexing with brackets

# %%
df[0, :]
# Out:
# shape: (1, 6)
# ┌──────────────┬──────────────────┬───────────────┬─────────────────┬────────────┬─────────────────┐
# │ device_name  ┆ machine_definiti ┆ variable_name ┆ value           ┆ timestamp  ┆ variable_attrib │
# │ ---          ┆ on               ┆ ---           ┆ ---             ┆ ---        ┆ ute             │
# │ str          ┆ ---              ┆ str           ┆ str             ┆ str        ┆ ---             │
# │              ┆ str              ┆               ┆                 ┆            ┆ str             │
# ╞══════════════╪══════════════════╪═══════════════╪═════════════════╪════════════╪═════════════════╡
# │ de512stmp223 ┆ spark-machine-ot ┆ teil1GapX     ┆ 0.498,0.496,0.4 ┆ 2025-12-10 ┆ lowerLimit:     │
# │              ┆ to-vision-dyna…  ┆               ┆ 96,0.498,0.496, ┆ 04:16:46   ┆ -0.06499,       │
# │              ┆                  ┆               ┆ …               ┆            ┆ upperLim…       │
# ...

# %%
df[:, 0]
# Out:
# shape: (2_408_396,)
# Series: 'device_name' [str]
# [
# 	"de512stmp223"
# 	"de512stmp223"
# 	"de512stmp226"
# 	"de512stmp223"
# 	"de512stmp226"
# 	…
# 	"de512stmp268"
# 	"de512stmp268"
# 	"de512stmp268"
# 	"de512stmp268"
# 	"de512stmp268"
# ]

# %%
df.filter(pl.col("variable_name") == "teil1GapX")
# Out:
# shape: (57_209, 6)
# ┌──────────────┬──────────────────┬───────────────┬─────────────────┬────────────┬─────────────────┐
# │ device_name  ┆ machine_definiti ┆ variable_name ┆ value           ┆ timestamp  ┆ variable_attrib │
# │ ---          ┆ on               ┆ ---           ┆ ---             ┆ ---        ┆ ute             │
# │ str          ┆ ---              ┆ str           ┆ str             ┆ str        ┆ ---             │
# │              ┆ str              ┆               ┆                 ┆            ┆ str             │
# ╞══════════════╪══════════════════╪═══════════════╪═════════════════╪════════════╪═════════════════╡
# │ de512stmp223 ┆ spark-machine-ot ┆ teil1GapX     ┆ 0.498,0.496,0.4 ┆ 2025-12-10 ┆ lowerLimit:     │
# │              ┆ to-vision-dyna…  ┆               ┆ 96,0.498,0.496, ┆ 04:16:46   ┆ -0.06499,       │
# │              ┆                  ┆               ┆ …               ┆            ┆ upperLim…       │
# ...

# %%
df.select(pl.col(['variable_name', 'value']))
# Out:
# shape: (2_408_396, 2)
# ┌──────────────────────────┬─────────────────────────────────┐
# │ variable_name            ┆ value                           │
# │ ---                      ┆ ---                             │
# │ str                      ┆ str                             │
# ╞══════════════════════════╪═════════════════════════════════╡
# │ teil1GapX                ┆ 0.498,0.496,0.496,0.498,0.496,… │
# │ teil1GapY                ┆ 0.497,0.489,0.491,0.484,0.487,… │
# │ iTeil2Rastfederdifferenz ┆ 0.0107,0.0152,0.0074,0.0123,0.… │
# │ iT1RastfederDeformiert   ┆ 59.543,62.944,58.544,61.577,62… │
# │ prfungTeil2BodySpk       ┆ 1.8878,1.8835,1.8934,1.8954,1.… │
# │ …                        ┆ …                               │
# │ spur2IKastenHinten       ┆ 0.979,0.981,0.986,0.976,0.982,… │
# │ spur2Wire                ┆ 1.713,1.712,1.713,1.713,1.714,… │
# │ spur2Iso                 ┆ 1.936,1.939,1.936,1.932,1.936,… │
# │ spur2Gap                 ┆ 0.194,0.192,0.184,0.194,0.189,… │
# ...

# %%
df.with_columns(
    [(pl.col("value") + pl.col('value')).alias("value_doubled")]
)
# Out:
# shape: (2_408_396, 7)
# ┌──────────────┬─────────────┬─────────────┬─────────────┬─────────────┬─────────────┬─────────────┐
# │ device_name  ┆ machine_def ┆ variable_na ┆ value       ┆ timestamp   ┆ variable_at ┆ value_doubl │
# │ ---          ┆ inition     ┆ me          ┆ ---         ┆ ---         ┆ tribute     ┆ ed          │
# │ str          ┆ ---         ┆ ---         ┆ str         ┆ str         ┆ ---         ┆ ---         │
# │              ┆ str         ┆ str         ┆             ┆             ┆ str         ┆ str         │
# ╞══════════════╪═════════════╪═════════════╪═════════════╪═════════════╪═════════════╪═════════════╡
# │ de512stmp223 ┆ spark-machi ┆ teil1GapX   ┆ 0.498,0.496 ┆ 2025-12-10  ┆ lowerLimit: ┆ 0.498,0.496 │
# │              ┆ ne-otto-vis ┆             ┆ ,0.496,0.49 ┆ 04:16:46    ┆ -0.06499,   ┆ ,0.496,0.49 │
# │              ┆ ion-dyna…   ┆             ┆ 8,0.496,…   ┆             ┆ upperLim…   ┆ 8,0.496,…   │
# ...
